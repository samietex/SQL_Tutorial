-- %% [markdown]
-- ![SQL Tutorial](SQL%20Tutorial%20Cover.png)
--
-- # SQL Tutorial
--
-- ### A Hands-On Companion to the *All About Data & More* SQL Curriculum
--
-- Welcome. This is where the SQL fundamentals from the newsletter turn into something you actually run yourself. Work through the notebooks in order, execute every query, and don't just read the answer, get the wrong answer first if that's what it takes to understand why the right one works.

-- %% [markdown]
-- > **Who this is for:** anyone starting the Data Analytics, Analytics Engineering, or Data Engineering track from the [Start Here roadmap](https://aaboutdata.substack.com/p/start-here-from-beginner-to-job-ready), and anyone who just wants a real, hands-on SQL Server tutorial. You don't need to be subscribed to the newsletter to use this repo, but the two are built to work together.

-- %% [markdown]
-- ## Getting Started
--
-- > **Prerequisites**
-- > - **SQL Server**: install the free [SQL Server Express Edition](https://www.microsoft.com/en-us/sql-server/sql-server-downloads) to follow along.
-- > - **SQL Server Management Studio (SSMS)**: the client used to connect to your local server and run these notebooks' queries.
--
-- 1. Install SQL Server Express Edition.
-- 2. Install and open SQL Server Management Studio (SSMS).
-- 3. Start with this notebook, then work through the numbered notebooks below in order.

-- %% [markdown]
-- ## A Note on SQL Server vs. SQL
--
-- Everything here runs on SQL Server, because you need one real engine to actually install and run queries against, not three. But the language you're learning is standard SQL: `SELECT`, `WHERE`, `JOIN`, `GROUP BY`, CTEs, and window functions all work the same way on MySQL, PostgreSQL, and everywhere else, they're part of the ANSI SQL standard, not something Microsoft invented for SQL Server specifically.
--
-- The handful of places where SQL Server does its own thing, mostly around changing data and table structure in `08a`/`08b`, get called out inline as they come up, so you know what's universal and what's specific to this one engine before you ever touch a different one.

-- %% [markdown]
-- ## Course Agenda
--
-- | # | Type | Module |
-- |---|------|--------|
-- | 1 | ![Newsletter Only](https://img.shields.io/badge/Newsletter_Only-9CA3AF) | What is a Database, and Why SQL (conceptual, no notebook, see the newsletter) |
-- | 2 | ![Hands-On](https://img.shields.io/badge/Hands--On-059669) | [01 - SQL Basics (SELECT, WHERE, ORDER BY)](<01 - SQL Basics (SELECT, WHERE, ORDER BY).ipynb>) |
-- | 3 | ![Hands-On](https://img.shields.io/badge/Hands--On-059669) | [02 - Aggregation (GROUP BY, HAVING, COUNT/SUM/AVG)](<02 - Aggregation (GROUP BY, HAVING, COUNT-SUM-AVG).ipynb>) |
-- | 4 | ![Hands-On](https://img.shields.io/badge/Hands--On-059669) | [03 - JOINs (INNER vs LEFT)](<03 - JOINs (INNER vs LEFT).ipynb>) |
-- | 5 | ![Hands-On](https://img.shields.io/badge/Hands--On-059669) | [04 - Subqueries to CTEs](<04 - Subqueries to CTEs.ipynb>) |
-- | 6 | ![Hands-On](https://img.shields.io/badge/Hands--On-059669) | [05 - Window Functions, Part 1](<05 - Window Functions, Part 1.ipynb>) |
-- | 7 | ![Coming Soon](https://img.shields.io/badge/Coming_Soon-9CA3AF) | Window Functions, Part 2 |
-- | 8a | ![Hands-On](https://img.shields.io/badge/Hands--On-059669) | [08a - Changing Data, Part 1 (INSERT, UPDATE, DELETE)](<08a - Changing Data, Part 1 - INSERT, UPDATE, DELETE.ipynb>) |
-- | 8b | ![Reference](https://img.shields.io/badge/Reference-0891B2) | [08b - Changing Data, Part 2 (CREATE & ALTER TABLE)](<08b - Changing Data, Part 2 - CREATE & ALTER TABLE.ipynb>) |
-- | 9 | ![Newsletter Only](https://img.shields.io/badge/Newsletter_Only-9CA3AF) | Thinking in Metrics (conceptual, no notebook, see the newsletter) |
-- | App A | ![Reference](https://img.shields.io/badge/Reference-0891B2) | [Appendix A - SQL Overview & Getting Started](<Appendix A - SQL Overview & Getting Started.ipynb>) |
--
-- Only Window Functions, Part 2 is still **Coming Soon**. Everything else in the sequence is written and ready to run.

-- %% [markdown]
-- ## What's Next
--
-- New notebooks land here as new lessons publish in the newsletter. If you spot a gap, an error, or want to suggest what should come after Window Functions, open an issue or a pull request.
--
-- Continue the reading version of this curriculum at [All About Data & More](https://aaboutdata.substack.com/p/start-here-from-beginner-to-job-ready).
--
-- ---
--
-- *SQL_Tutorial* is written and maintained by Samuel Shaibu as part of *All About Data & More*. Licensed under [MIT](LICENSE).
